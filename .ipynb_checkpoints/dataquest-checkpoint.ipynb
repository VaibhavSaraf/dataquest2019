# %% [markdown]
# # DATAQUEST

# %%
# %reload_ext autoreload
# %autoreload 2

# %matplotlib inline

# %% [markdown]
# ## Importing libraries

# %%
from fastai.imports import *
from fastai.structured import *

from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor , RandomForestClassifier
import re
import seaborn as sns

from sklearn import metrics

# %%
train_map = []
test_map = []

# %% [markdown]
# ## Getting data using pandas

# %%
PATH = './data/'

# %%
# !ls {PATH}
# Out:
# sample_submission.csv  test.csv  train.csv

# %%
train_raw = pd.read_csv(f'{PATH}train.csv',low_memory=False,parse_dates=['opened_at'])

# %%
test_raw = pd.read_csv(f'{PATH}test.csv',low_memory=False,parse_dates=['opened_at'])

# %% [markdown]
# ##  Fuctions

# %%
def display_all(df):
    with pd.option_context("display.max_rows", 1000, "display.max_columns", 1000): 
        display(df)

# %%
def print_score(m):
    print(metrics.mean_absolute_error(m.predict(X_train),y_train),metrics.mean_absolute_error(m.predict(X_valid),y_valid))

# %%
def put_in_metrics(n):
    train_map.append(metrics.mean_absolute_error(n.predict(X_train),y_train))
    test_map.append(metrics.mean_absolute_error(n.predict(X_valid),y_valid))

# %% [markdown]
# ## EDA (DATA PREPROCESSING)

# %%
train_raw['target_days'].describe()
# Out:
# count    20000.000000
# mean        13.520050
# std         22.940033
# min          0.000000
# 25%          5.000000
# 50%          6.000000
# 75%         14.000000
# max        341.000000
# Name: target_days, dtype: float64

# %%
sns.distplot(train_raw['target_days'])

# %%
print('Skewness %f' % train_raw['target_days'].skew())
print('Kurtosis %f' % train_raw['target_days'].kurt())
# Out:
# Skewness 6.662243
# Kurtosis 56.909297

# %%
train_raw.shape , test_raw.shape
# Out:
# ((20000, 19), (4918, 18))

# %%
train_raw.dtypes
# Out:
# Id                            object
# reassignment_count             int64
# reopen_count                   int64
# update_count                   int64
# made_sla                        bool
# opened_by                     object
# opened_at             datetime64[ns]
# contact_type                  object
# location                      object
# category                      object
# subcategory                   object
# impact                        object
# urgency                       object
# priority                      object
# assigned_to                   object
# knowledge                       bool
# notify                        object
# vendor                        object
# target_days                    int64
# dtype: object

# %%
train_raw.head().T
# Out:
#                                       0                    1  \
# Id                           INC0000045           INC0000047
# reassignment_count                    0                    0
# reopen_count                          0                    0
# update_count                          0                    0
# made_sla                           True                 True
# opened_by                  Opened by  8       Opened by  397
# opened_at           2016-02-29 01:16:00  2016-02-29 04:40:00
# contact_type                      Phone                Phone
# location                   Location 143         Location 165
# category                    Category 55          Category 40
# subcategory             Subcategory 170      Subcategory 215
# impact                       2 - Medium           2 - Medium
# urgency                      2 - Medium           2 - Medium
# priority                   3 - Moderate         3 - Moderate
# assigned_to                         NaN          Resolver 89
# knowledge                          True                 True
# notify                    Do Not Notify        Do Not Notify
# vendor                              NaN                  NaN
# target_days                           5                    6
#
#                                       2                    3  \
# Id                           INC0000057           INC0000060
# reassignment_count                    0                    0
# reopen_count                          0                    0
# update_count                          0                    0
# made_sla                           True                 True
# opened_by                  Opened by  8       Opened by  180
# opened_at           2016-02-29 06:10:00  2016-02-29 06:38:00
# contact_type                      Phone                Phone
# location                   Location 204         Location 204
# category                    Category 20           Category 9
# subcategory             Subcategory 125       Subcategory 97
# impact                       2 - Medium           2 - Medium
# urgency                      2 - Medium           2 - Medium
# priority                   3 - Moderate         3 - Moderate
# assigned_to                         NaN         Resolver 125
# knowledge                          True                 True
# notify                    Do Not Notify        Do Not Notify
# vendor                              NaN                  NaN
# target_days                           5                    7
#
#                                       4
# Id                           INC0000062
# reassignment_count                    0
# reopen_count                          0
# update_count                          0
# made_sla                           True
# opened_by                Opened by  180
# opened_at           2016-02-29 06:58:00
# contact_type                      Phone
# location                    Location 93
# category                    Category 53
# subcategory             Subcategory 168
# impact                       2 - Medium
# urgency                      2 - Medium
# priority                   3 - Moderate
# assigned_to                         NaN
# knowledge                          True
# notify                    Do Not Notify
# vendor                              NaN
# target_days                           5

# %% [markdown]
# ##  Dropping columns

# %%
train_raw.drop(columns=['reassignment_count','reopen_count'],inplace=True)

# %%
train_raw.drop('Id',axis=1,inplace=True)

# %%
train_raw.drop('vendor',axis=1,inplace=True)

# %% [markdown]
# ## Removing outliers

# %% [markdown]
# #### Outliers in update_count, opened_by

# %%
train_raw.drop(train_raw[train_raw['update_count'] !=0].index,inplace=True)

# %%
train_raw.update_count.value_counts()
# Out:
# 0    19995
# Name: update_count, dtype: int64

# %% [markdown]
# ####  The columns opened_by,location,category,subcategory can be made integer directly by stripping away the alphacharacters .  The columns impact,urgency,priority could be splitted.

# %%
add_datepart(train_raw,'opened_at')

# %% [markdown]
# ## Splitting column data

# %%
train_raw['opened_by'] = train_raw['opened_by'].str.split(expand=True)[2]
# train_raw.opened_by.astype('int')

# %%
train_raw['opened_by'].isnull().sum()
# Out:
# 714

# %%
train_raw.dtypes
# Out:
# update_count                  int64
# made_sla                       bool
# opened_by                    object
# contact_type                 object
# location                     object
# category                     object
# subcategory                  object
# impact                       object
# urgency                      object
# priority                     object
# assigned_to                  object
# knowledge                      bool
# notify                       object
# target_days                   int64
# opened_atYear                 int64
# opened_atMonth                int64
# opened_atWeek                 int64
# opened_atDay                  int64
# opened_atDayofweek            int64
# opened_atDayofyear            int64
# opened_atIs_month_end          bool
# opened_atIs_month_start        bool
# opened_atIs_quarter_end        bool
# opened_atIs_quarter_start      bool
# opened_atIs_year_end           bool
# opened_atIs_year_start         bool
# opened_atElapsed              int64
# dtype: object

# %%
train_raw.opened_by.astype('int',errors='ignore')
# Out:
# 0          8
# 1        397
# 2          8
# 3        180
# 4        180
# 5        180
# 6        131
# 7        131
# 8         24
# 9        180
# 10       131
# 11       180
# 12        40
# 13       433
# 14       180
# 15       180
# 16       180
# 17        24
# 18       131
# 19       433
# 20       180
# 21        24
# 22       180
# 23       180
# 24       180
# 25        40
# 26       131
# 27       433
# 28        24
# 29       180
#         ...
# 19970     17
# 19971     55
# 19972     24
# 19973     70
# 19974     24
# 19975     17
# 19976     17
# 19977     24
# 19978     17
# 19979    301
# 19980     17
# 19981    501
# 19982     55
# 19983     17
# 19984     24
# 19985     17
# 19986     17
# 19987     24
# 19988     24
# 19989     17
# 19990     24
# 19991    301
# 19992    131
# 19993     62
# 19994     24
# 19995     17
# 19996     17
# 19997     24
# 19998     24
# 19999     55
# Name: opened_by, Length: 19995, dtype: object

# %%
train_raw['opened_by_na'] = train_raw['opened_by'].copy().isna()

# %%
train_raw[train_raw['opened_by'].isna()] = 0

# %%
train_raw.opened_by_na.value_counts()

# %% [markdown]
# #### Now since we have many null values and we got to deal with that. We could do one hot encoding . Make a column of opened_by_na and then give 1 to value having NaN values and 0 to rest . And then in opened_by column we could make all of them as 0. Maybe this is all is pre implemented in a function in fastai . Got to check that.

# %%
train_cats(train_raw)

# %%
train_raw.impact.cat.set_categories(['3 - Low','2 - Medium','1 - High'],ordered=True,inplace=True)
train_raw.urgency.cat.set_categories(['3 - Low','2 - Medium','1 - High'],ordered=True,inplace=True)
train_raw.priority.cat.set_categories(train_raw.priority.cat.categories[::-1],ordered=True,inplace=True)

# %%
train_raw.isnull().sum().sort_index()/len(train_raw)
# Out:
# assigned_to                  0.270368
# category                     0.001300
# contact_type                 0.000000
# impact                       0.000000
# knowledge                    0.000000
# location                     0.002601
# made_sla                     0.000000
# notify                       0.000000
# opened_atDay                 0.000000
# opened_atDayofweek           0.000000
# opened_atDayofyear           0.000000
# opened_atElapsed             0.000000
# opened_atIs_month_end        0.000000
# opened_atIs_month_start      0.000000
# opened_atIs_quarter_end      0.000000
# opened_atIs_quarter_start    0.000000
# opened_atIs_year_end         0.000000
# opened_atIs_year_start       0.000000
# opened_atMonth               0.000000
# opened_atWeek                0.000000
# opened_atYear                0.000000
# opened_by                    0.035709
# priority                     0.000000
# subcategory                  0.002801
# target_days                  0.000000
# update_count                 0.000000
# urgency                      0.000000
# dtype: float64

# %% [markdown]
# ## Data after preprocessing

# %%
display_all(train_raw.head().T)
# Out:
#                                          0                1                2  \
# update_count                             0                0                0
# made_sla                              True             True             True
# opened_by                                8              397                8
# contact_type                         Phone            Phone            Phone
# location                      Location 143     Location 165     Location 204
# category                       Category 55      Category 40      Category 20
# subcategory                Subcategory 170  Subcategory 215  Subcategory 125
# impact                          2 - Medium       2 - Medium       2 - Medium
# urgency                         2 - Medium       2 - Medium       2 - Medium
# priority                      3 - Moderate     3 - Moderate     3 - Moderate
# assigned_to                            NaN      Resolver 89              NaN
# knowledge                             True             True             True
# notify                       Do Not Notify    Do Not Notify    Do Not Notify
# target_days                              5                6                5
# opened_atYear                         2016             2016             2016
# opened_atMonth                           2                2                2
# opened_atWeek                            9                9                9
# opened_atDay                            29               29               29
# opened_atDayofweek                       0                0                0
# opened_atDayofyear                      60               60               60
# opened_atIs_month_end                 True             True             True
# opened_atIs_month_start              False            False            False
# opened_atIs_quarter_end              False            False            False
# opened_atIs_quarter_start            False            False            False
# opened_atIs_year_end                 False            False            False
# opened_atIs_year_start               False            False            False
# opened_atElapsed                1456708560       1456720800       1456726200
#
#                                         3                4
# update_count                            0                0
# made_sla                             True             True
# opened_by                             180              180
# contact_type                        Phone            Phone
# location                     Location 204      Location 93
# category                       Category 9      Category 53
# subcategory                Subcategory 97  Subcategory 168
# impact                         2 - Medium       2 - Medium
# urgency                        2 - Medium       2 - Medium
# priority                     3 - Moderate     3 - Moderate
# assigned_to                  Resolver 125              NaN
# knowledge                            True             True
# notify                      Do Not Notify    Do Not Notify
# target_days                             7                5
# opened_atYear                        2016             2016
# opened_atMonth                          2                2
# opened_atWeek                           9                9
# opened_atDay                           29               29
# opened_atDayofweek                      0                0
# opened_atDayofyear                     60               60
# opened_atIs_month_end                True             True
# opened_atIs_month_start             False            False
# opened_atIs_quarter_end             False            False
# opened_atIs_quarter_start           False            False
# opened_atIs_year_end                False            False
# opened_atIs_year_start              False            False
# opened_atElapsed               1456727880       1456729080

# %%
train , y, nas = proc_df(train_raw,'target_days')

# %%
def split_vals(a,n): return a[:n].copy() , a[n:].copy()

n_valid = 3000 
n_trn = len(train) - n_valid
X_train , X_valid = split_vals(train,n_trn)
y_train , y_valid = split_vals(y,n_trn)

X_train.shape , X_valid.shape , y_train.shape , y_valid.shape
# Out:
# ((16995, 26), (3000, 26), (16995,), (3000,))

# %%
# def rmse(x,y): return math.sqrt(((x-y)**2).mean())

# def print_score(m):
#     res = [rmse(m.predict(X_train), y_train), rmse(m.predict(X_valid), y_valid),
#                 m.score(X_train, y_train), m.score(X_valid, y_valid)]
#     if hasattr(m, 'oob_score_'): res.append(m.oob_score_)
#     print(res)

# %%
m = RandomForestRegressor(n_jobs=-1,random_state=3)
m.fit(X_train,y_train)
# Out:
# /home/vaibhav/anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#                       max_features='auto', max_leaf_nodes=None,
#                       min_impurity_decrease=0.0, min_impurity_split=None,
#                       min_samples_leaf=1, min_samples_split=2,
#                       min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#                       oob_score=False, random_state=3, verbose=0,
#                       warm_start=False)

# %%
print_score(m)
# Out:
# 3.159887810140237 24.623

# %%
n = RandomForestClassifier(n_jobs=-1,random_state=5)
n.fit(X_train,y_train)
# Out:
# /home/vaibhav/anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=-1,
#                        oob_score=False, random_state=5, verbose=0,
#                        warm_start=False)

# %%
print_score(n)
# Out:
# 0.3649897028537805 5.978666666666666

# %%
 put_in_metrics(n)

# %%
train_map , test_map
# Out:
# ([0.3649897028537805], [5.978666666666666])

# %% [markdown]
# # TEST

# %%
Id = test_raw['Id'].copy()

# %%
test_raw.drop(columns=['Id','vendor'],inplace=True)

# %%
add_datepart(test_raw,'opened_at')

# %%
apply_cats(test_raw,train_raw)

# %%
test , _, _ = proc_df(test_raw)

# %%
train_raw.T
# Out:
#                                      0                1                2      \
# update_count                             0                0                0
# made_sla                              True             True             True
# opened_by                                8              397                8
# contact_type                         Phone            Phone            Phone
# location                      Location 143     Location 165     Location 204
# category                       Category 55      Category 40      Category 20
# subcategory                Subcategory 170  Subcategory 215  Subcategory 125
# impact                          2 - Medium       2 - Medium       2 - Medium
# urgency                         2 - Medium       2 - Medium       2 - Medium
# priority                      3 - Moderate     3 - Moderate     3 - Moderate
# assigned_to                            NaN      Resolver 89              NaN
# knowledge                             True             True             True
# notify                       Do Not Notify    Do Not Notify    Do Not Notify
# target_days                              5                6                5
# opened_atYear                         2016             2016             2016
# opened_atMonth                           2                2                2
# opened_atWeek                            9                9                9
# opened_atDay                            29               29               29
# opened_atDayofweek                       0                0                0
# opened_atDayofyear                      60               60               60
# opened_atIs_month_end                 True             True             True
# opened_atIs_month_start              False            False            False
# opened_atIs_quarter_end              False            False            False
# opened_atIs_quarter_start            False            False            False
# opened_atIs_year_end                 False            False            False
# opened_atIs_year_start               False            False            False
# opened_atElapsed                1456708560       1456720800       1456726200
#
#                                     3                4                5      \
# update_count                            0                0                0
# made_sla                             True             True             True
# opened_by                             180              180              180
# contact_type                        Phone            Phone            Phone
# location                     Location 204      Location 93      Location 93
# category                       Category 9      Category 53      Category 20
# subcategory                Subcategory 97  Subcategory 168  Subcategory 125
# impact                         2 - Medium       2 - Medium       2 - Medium
# urgency                        2 - Medium       2 - Medium       2 - Medium
# priority                     3 - Moderate     3 - Moderate     3 - Moderate
# assigned_to                  Resolver 125              NaN              NaN
# knowledge                            True             True             True
# notify                      Do Not Notify    Do Not Notify    Do Not Notify
# target_days                             7                5                5
# opened_atYear                        2016             2016             2016
# opened_atMonth                          2                2                2
# opened_atWeek                           9                9                9
# opened_atDay                           29               29               29
# opened_atDayofweek                      0                0                0
# opened_atDayofyear                     60               60               60
# opened_atIs_month_end                True             True             True
# opened_atIs_month_start             False            False            False
# opened_atIs_quarter_end             False            False            False
# opened_atIs_quarter_start           False            False            False
# opened_atIs_year_end                False            False            False
# opened_atIs_year_start              False            False            False
# opened_atElapsed               1456727880       1456729080       1456729680
#
#                                      6                7                8      \
# update_count                             0                0                0
# made_sla                              True             True             True
# opened_by                              131              131               24
# contact_type                         Phone            Phone            Phone
# location                      Location 143     Location 108     Location 161
# category                       Category 53      Category 44      Category 55
# subcategory                Subcategory 168  Subcategory 229  Subcategory 185
# impact                          2 - Medium       2 - Medium       2 - Medium
# urgency                         2 - Medium       2 - Medium       2 - Medium
# priority                      3 - Moderate     3 - Moderate     3 - Moderate
# assigned_to                    Resolver 78     Resolver 216              NaN
# knowledge                             True             True             True
# notify                       Do Not Notify    Do Not Notify    Do Not Notify
# target_days                              8                7                7
# opened_atYear                         2016             2016             2016
# opened_atMonth                           2                2                2
# opened_atWeek                            9                9                9
# opened_atDay                            29               29               29
# opened_atDayofweek                       0                0                0
# opened_atDayofyear                      60               60               60
# opened_atIs_month_end                 True             True             True
# opened_atIs_month_start              False            False            False
# opened_atIs_quarter_end              False            False            False
# opened_atIs_quarter_start            False            False            False
# opened_atIs_year_end                 False            False            False
# opened_atIs_year_start               False            False            False
# opened_atElapsed                1456729800       1456731480       1456732980
#
#                                      9      ...            19990  \
# update_count                             0  ...                0
# made_sla                              True  ...             True
# opened_by                              180  ...               24
# contact_type                         Phone  ...            Phone
# location                      Location 143  ...     Location 161
# category                        Category 9  ...       Category 9
# subcategory                Subcategory 110  ...  Subcategory 164
# impact                          2 - Medium  ...       2 - Medium
# urgency                         2 - Medium  ...       2 - Medium
# priority                      3 - Moderate  ...     3 - Moderate
# assigned_to                   Resolver 236  ...      Resolver 24
# knowledge                             True  ...            False
# notify                       Do Not Notify  ...    Do Not Notify
# target_days                              7  ...                6
# opened_atYear                         2016  ...             2016
# opened_atMonth                           2  ...                5
# opened_atWeek                            9  ...               19
# opened_atDay                            29  ...               11
# opened_atDayofweek                       0  ...                2
# opened_atDayofyear                      60  ...              132
# opened_atIs_month_end                 True  ...            False
# opened_atIs_month_start              False  ...            False
# opened_atIs_quarter_end              False  ...            False
# opened_atIs_quarter_start            False  ...            False
# opened_atIs_year_end                 False  ...            False
# opened_atIs_year_start               False  ...            False
# opened_atElapsed                1456732980  ...       1462956060
#
#                                      19991            19992            19993  \
# update_count                             0                0                0
# made_sla                              True             True             True
# opened_by                              301              131               62
# contact_type                         Phone            Phone            Phone
# location                       Location 56     Location 161     Location 143
# category                       Category 37      Category 42      Category 53
# subcategory                Subcategory 123  Subcategory 223  Subcategory 303
# impact                          2 - Medium       2 - Medium       2 - Medium
# urgency                         2 - Medium       2 - Medium       2 - Medium
# priority                      3 - Moderate     3 - Moderate     3 - Moderate
# assigned_to                    Resolver 82     Resolver 194      Resolver 33
# knowledge                            False            False            False
# notify                       Do Not Notify    Do Not Notify    Do Not Notify
# target_days                            217                5                5
# opened_atYear                         2016             2016             2016
# opened_atMonth                           5                5                5
# opened_atWeek                           19               19               19
# opened_atDay                            11               11               11
# opened_atDayofweek                       2                2                2
# opened_atDayofyear                     132              132              132
# opened_atIs_month_end                False            False            False
# opened_atIs_month_start              False            False            False
# opened_atIs_quarter_end              False            False            False
# opened_atIs_quarter_start            False            False            False
# opened_atIs_year_end                 False            False            False
# opened_atIs_year_start               False            False            False
# opened_atElapsed                1462956060       1462956120       1462956240
#
#                                      19994            19995            19996  \
# update_count                             0                0                0
# made_sla                              True             True             True
# opened_by                               24               17               17
# contact_type                         Phone            Phone            Phone
# location                      Location 108     Location 204      Location 93
# category                       Category 20      Category 42      Category 37
# subcategory                Subcategory 174  Subcategory 223  Subcategory 174
# impact                          2 - Medium       2 - Medium       2 - Medium
# urgency                         2 - Medium       2 - Medium       2 - Medium
# priority                      3 - Moderate     3 - Moderate     3 - Moderate
# assigned_to                    Resolver 93      Resolver 13      Resolver 83
# knowledge                            False            False            False
# notify                       Do Not Notify    Do Not Notify    Do Not Notify
# target_days                              6                5                5
# opened_atYear                         2016             2016             2016
# opened_atMonth                           5                5                5
# opened_atWeek                           19               19               19
# opened_atDay                            11               11               11
# opened_atDayofweek                       2                2                2
# opened_atDayofyear                     132              132              132
# opened_atIs_month_end                False            False            False
# opened_atIs_month_start              False            False            False
# opened_atIs_quarter_end              False            False            False
# opened_atIs_quarter_start            False            False            False
# opened_atIs_year_end                 False            False            False
# opened_atIs_year_start               False            False            False
# opened_atElapsed                1462956240       1462956300       1462956360
#
#                                      19997            19998            19999
# update_count                             0                0                0
# made_sla                              True             True             True
# opened_by                               24               24               55
# contact_type                         Phone            Phone            Phone
# location                       Location 97      Location 51     Location 204
# category                       Category 42      Category 53      Category 26
# subcategory                Subcategory 223  Subcategory 130  Subcategory 275
# impact                          2 - Medium       2 - Medium       2 - Medium
# urgency                         2 - Medium       2 - Medium       2 - Medium
# priority                      3 - Moderate     3 - Moderate     3 - Moderate
# assigned_to                    Resolver 17              NaN              NaN
# knowledge                            False            False            False
# notify                       Do Not Notify    Do Not Notify    Do Not Notify
# target_days                              5               11                5
# opened_atYear                         2016             2016             2016
# opened_atMonth                           5                5                5
# opened_atWeek                           19               19               19
# opened_atDay                            11               11               11
# opened_atDayofweek                       2                2                2
# opened_atDayofyear                     132              132              132
# opened_atIs_month_end                False            False            False
# opened_atIs_month_start              False            False            False
# opened_atIs_quarter_end              False            False            False
# opened_atIs_quarter_start            False            False            False
# opened_atIs_year_end                 False            False            False
# opened_atIs_year_start               False            False            False
# opened_atElapsed                1462956600       1462956660       1462956720
#
# [27 rows x 19995 columns]

# %%
test_raw.T
# Out:
#                                       0                1              2     \
# reassignment_count                       0                0              0
# reopen_count                             0                0              0
# update_count                             0                0              0
# made_sla                              True             True           True
# opened_by                              NaN              NaN            NaN
# contact_type                         Phone            Phone          Phone
# location                      Location 161      Location 93   Location 161
# category                        Category 9      Category 23    Category 32
# subcategory                Subcategory 164  Subcategory 174  Subcategory 9
# impact                          2 - Medium       2 - Medium     2 - Medium
# urgency                         2 - Medium       2 - Medium     2 - Medium
# priority                      3 - Moderate     3 - Moderate   3 - Moderate
# assigned_to                   Resolver 249     Resolver 233   Resolver 219
# knowledge                            False            False          False
# notify                       Do Not Notify    Do Not Notify  Do Not Notify
# opened_atYear                         2016             2016           2016
# opened_atMonth                           5                5              5
# opened_atWeek                           19               19             19
# opened_atDay                            11               11             11
# opened_atDayofweek                       2                2              2
# opened_atDayofyear                     132              132            132
# opened_atIs_month_end                False            False          False
# opened_atIs_month_start              False            False          False
# opened_atIs_quarter_end              False            False          False
# opened_atIs_quarter_start            False            False          False
# opened_atIs_year_end                 False            False          False
# opened_atIs_year_start               False            False          False
# opened_atElapsed                1462956720       1462956780     1462956900
#
#                                       3                4                5     \
# reassignment_count                       0                0                0
# reopen_count                             0                0                0
# update_count                             0                0                0
# made_sla                              True             True             True
# opened_by                              NaN              NaN              NaN
# contact_type                         Phone            Phone            Phone
# location                      Location 143     Location 204      Location 51
# category                       Category 57      Category 57      Category 32
# subcategory                Subcategory 170  Subcategory 146  Subcategory 300
# impact                          2 - Medium       2 - Medium       2 - Medium
# urgency                         2 - Medium       2 - Medium       2 - Medium
# priority                      3 - Moderate     3 - Moderate     3 - Moderate
# assigned_to                     Resolver 7      Resolver 76              NaN
# knowledge                            False            False            False
# notify                       Do Not Notify    Do Not Notify    Do Not Notify
# opened_atYear                         2016             2016             2016
# opened_atMonth                           5                5                5
# opened_atWeek                           19               19               19
# opened_atDay                            11               11               11
# opened_atDayofweek                       2                2                2
# opened_atDayofyear                     132              132              132
# opened_atIs_month_end                False            False            False
# opened_atIs_month_start              False            False            False
# opened_atIs_quarter_end              False            False            False
# opened_atIs_quarter_start            False            False            False
# opened_atIs_year_end                 False            False            False
# opened_atIs_year_start               False            False            False
# opened_atElapsed                1462957140       1462957140       1462957140
#
#                                       6                7                8     \
# reassignment_count                       0                0                0
# reopen_count                             0                0                0
# update_count                             0                0                0
# made_sla                              True             True             True
# opened_by                              NaN              NaN              NaN
# contact_type                         Phone            Phone            Phone
# location                      Location 204     Location 204      Location 55
# category                       Category 23      Category 57      Category 42
# subcategory                Subcategory 174  Subcategory 170  Subcategory 223
# impact                          2 - Medium       2 - Medium       2 - Medium
# urgency                         2 - Medium       2 - Medium       2 - Medium
# priority                      3 - Moderate     3 - Moderate     3 - Moderate
# assigned_to                   Resolver 125     Resolver 140      Resolver 33
# knowledge                            False            False            False
# notify                       Do Not Notify    Do Not Notify    Do Not Notify
# opened_atYear                         2016             2016             2016
# opened_atMonth                           5                5                5
# opened_atWeek                           19               19               19
# opened_atDay                            11               11               11
# opened_atDayofweek                       2                2                2
# opened_atDayofyear                     132              132              132
# opened_atIs_month_end                False            False            False
# opened_atIs_month_start              False            False            False
# opened_atIs_quarter_end              False            False            False
# opened_atIs_quarter_start            False            False            False
# opened_atIs_year_end                 False            False            False
# opened_atIs_year_start               False            False            False
# opened_atElapsed                1462957200       1462957200       1462957260
#
#                                     9     ...            4908            4909  \
# reassignment_count                     0  ...               0               0
# reopen_count                           0  ...               0               0
# update_count                           0  ...               0               0
# made_sla                            True  ...            True            True
# opened_by                            NaN  ...             NaN             NaN
# contact_type                       Phone  ...             NaN             NaN
# location                    Location 136  ...             NaN             NaN
# category                     Category 32  ...             NaN             NaN
# subcategory                Subcategory 9  ...  Subcategory 10  Subcategory 10
# impact                        2 - Medium  ...         3 - Low         3 - Low
# urgency                       2 - Medium  ...      2 - Medium      2 - Medium
# priority                    3 - Moderate  ...         4 - Low         4 - Low
# assigned_to                          NaN  ...             NaN             NaN
# knowledge                          False  ...           False           False
# notify                     Do Not Notify  ...   Do Not Notify   Do Not Notify
# opened_atYear                       2016  ...            2017            2017
# opened_atMonth                         5  ...               2               2
# opened_atWeek                         19  ...               7               7
# opened_atDay                          11  ...              13              14
# opened_atDayofweek                     2  ...               0               1
# opened_atDayofyear                   132  ...              44              45
# opened_atIs_month_end              False  ...           False           False
# opened_atIs_month_start            False  ...           False           False
# opened_atIs_quarter_end            False  ...           False           False
# opened_atIs_quarter_start          False  ...           False           False
# opened_atIs_year_end               False  ...           False           False
# opened_atIs_year_start             False  ...           False           False
# opened_atElapsed              1462957260  ...      1486985460      1487070660
#
#                                      4910            4911            4912  \
# reassignment_count                      0               0               0
# reopen_count                            0               0               0
# update_count                            0               0               0
# made_sla                             True            True            True
# opened_by                             NaN             NaN             NaN
# contact_type                          NaN             NaN             NaN
# location                              NaN             NaN             NaN
# category                              NaN             NaN             NaN
# subcategory                Subcategory 10  Subcategory 10  Subcategory 10
# impact                            3 - Low         3 - Low         3 - Low
# urgency                        2 - Medium      2 - Medium      2 - Medium
# priority                          4 - Low         4 - Low         4 - Low
# assigned_to                           NaN             NaN             NaN
# knowledge                           False           False           False
# notify                      Do Not Notify   Do Not Notify   Do Not Notify
# opened_atYear                        2017            2017            2017
# opened_atMonth                          2               2               2
# opened_atWeek                           7               7               7
# opened_atDay                           14              14              15
# opened_atDayofweek                      1               1               2
# opened_atDayofyear                     45              45              46
# opened_atIs_month_end               False           False           False
# opened_atIs_month_start             False           False           False
# opened_atIs_quarter_end             False           False           False
# opened_atIs_quarter_start           False           False           False
# opened_atIs_year_end                False           False           False
# opened_atIs_year_start              False           False           False
# opened_atElapsed               1487070900      1487097060      1487123520
#
#                                       4913            4914           4915  \
# reassignment_count                       0               0              0
# reopen_count                             0               0              0
# update_count                             0               0              0
# made_sla                              True            True           True
# opened_by                              NaN             NaN            NaN
# contact_type                         Email             NaN          Phone
# location                      Location 188             NaN   Location 135
# category                               NaN             NaN            NaN
# subcategory                Subcategory 177  Subcategory 10            NaN
# impact                          2 - Medium         3 - Low     2 - Medium
# urgency                         2 - Medium      2 - Medium     2 - Medium
# priority                      3 - Moderate         4 - Low   3 - Moderate
# assigned_to                     Resolver 6             NaN            NaN
# knowledge                            False           False          False
# notify                       Do Not Notify   Do Not Notify  Do Not Notify
# opened_atYear                         2017            2017           2017
# opened_atMonth                           2               2              2
# opened_atWeek                            7               7              7
# opened_atDay                            15              15             15
# opened_atDayofweek                       2               2              2
# opened_atDayofyear                      46              46             46
# opened_atIs_month_end                False           False          False
# opened_atIs_month_start              False           False          False
# opened_atIs_quarter_end              False           False          False
# opened_atIs_quarter_start            False           False          False
# opened_atIs_year_end                 False           False          False
# opened_atIs_year_start               False           False          False
# opened_atElapsed                1487124120      1487142540     1487159880
#
#                                       4916             4917
# reassignment_count                       0                0
# reopen_count                             0                0
# update_count                             0                0
# made_sla                              True             True
# opened_by                              NaN              NaN
# contact_type                         Email            Email
# location                      Location 204     Location 204
# category                       Category 42      Category 42
# subcategory                Subcategory 223  Subcategory 223
# impact                          2 - Medium       2 - Medium
# urgency                         2 - Medium       2 - Medium
# priority                      3 - Moderate     3 - Moderate
# assigned_to                    Resolver 10      Resolver 10
# knowledge                            False            False
# notify                       Do Not Notify    Do Not Notify
# opened_atYear                         2017             2017
# opened_atMonth                           2                2
# opened_atWeek                            7                7
# opened_atDay                            16               16
# opened_atDayofweek                       3                3
# opened_atDayofyear                      47               47
# opened_atIs_month_end                False            False
# opened_atIs_month_start              False            False
# opened_atIs_quarter_end              False            False
# opened_atIs_quarter_start            False            False
# opened_atIs_year_end                 False            False
# opened_atIs_year_start               False            False
# opened_atElapsed                1487236140       1487254620
#
# [28 rows x 4918 columns]

# %%
y_test = n.predict(test).astype('int')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-204-e5f64e6447a7> in <module>
# ----> 1 y_test = n.predict(test).astype('int')
#
# ~/anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict(self, X)
#     543             The predicted classes.
#     544         """
# --> 545         proba = self.predict_proba(X)
#     546
#     547         if self.n_outputs_ == 1:
#
# ~/anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/ensemble/forest.py in predict_proba(self, X)
#     586         check_is_fitted(self, 'estimators_')
#     587         # Check data
# --> 588         X = self._validate_X_predict(X)
#     589
#     590         # Assign chunk of trees to jobs
#
# ~/anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/ensemble/forest.py in _validate_X_predict(self, X)
#     357                                  "call `fit` before exploiting the model.")
#     358
# --> 359         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     360
#     361     @property
#
# ~/anaconda3/envs/ml/lib/python3.6/site-packages/sklearn/tree/tree.py in _validate_X_predict(self, X, check_input)
#     400                              "match the input. Model n_features is %s and "
#     401                              "input n_features is %s "
# --> 402                              % (self.n_features_, n_features))
#     403
#     404         return X
#
# ValueError: Number of features of the model must match the input. Model n_features is 26 and input n_features is 28

# %%
y_test

# %%
dict = {
    'Id':Id,
    'target_days':y_test
}

# %%
submit = pd.DataFrame(dict)

# %%
submit.to_csv('submission/submit2.csv',header=True,index=False)
