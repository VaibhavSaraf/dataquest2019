# %%
# %load_ext autoreload
# %autoreload 2
# %autosave 5

# %matplotlib inline
# Out:
# Autosaving every 5 seconds

# %%
from fastai.imports import *
from fastai.structured import *

from pandas_summary import DataFrameSummary
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier , ExtraTreesRegressor
from IPython.display import display

from sklearn import metrics

from sklearn.preprocessing import LabelEncoder,OneHotEncoder
from sklearn import linear_model
from sklearn.metrics import mean_squared_error, r2_score
import seaborn as sns

# %%
PATH = './dataq'

# %%
# !ls
# Out:
# fastai	run.ipynb  sample.ipynb  sample_submission.csv	test.csv  train.csv

# %%
df_raw = pd.read_csv('train.csv',low_memory = False)

# %%
df_raw.T
# Out:
#                                   0                    1      \
# Id                           INC0000045           INC0000047
# reassignment_count                    0                    0
# reopen_count                          0                    0
# update_count                          0                    0
# made_sla                           True                 True
# opened_by                  Opened by  8       Opened by  397
# opened_at           2016-02-29 01:16:00  2016-02-29 04:40:00
# contact_type                      Phone                Phone
# location                   Location 143         Location 165
# category                    Category 55          Category 40
# subcategory             Subcategory 170      Subcategory 215
# impact                       2 - Medium           2 - Medium
# urgency                      2 - Medium           2 - Medium
# priority                   3 - Moderate         3 - Moderate
# assigned_to                         NaN          Resolver 89
# knowledge                          True                 True
# notify                    Do Not Notify        Do Not Notify
# vendor                              NaN                  NaN
# target_days                           5                    6
#
#                                   2                    3      \
# Id                           INC0000057           INC0000060
# reassignment_count                    0                    0
# reopen_count                          0                    0
# update_count                          0                    0
# made_sla                           True                 True
# opened_by                  Opened by  8       Opened by  180
# opened_at           2016-02-29 06:10:00  2016-02-29 06:38:00
# contact_type                      Phone                Phone
# location                   Location 204         Location 204
# category                    Category 20           Category 9
# subcategory             Subcategory 125       Subcategory 97
# impact                       2 - Medium           2 - Medium
# urgency                      2 - Medium           2 - Medium
# priority                   3 - Moderate         3 - Moderate
# assigned_to                         NaN         Resolver 125
# knowledge                          True                 True
# notify                    Do Not Notify        Do Not Notify
# vendor                              NaN                  NaN
# target_days                           5                    7
#
#                                   4                    5      \
# Id                           INC0000062           INC0000063
# reassignment_count                    0                    0
# reopen_count                          0                    0
# update_count                          0                    0
# made_sla                           True                 True
# opened_by                Opened by  180       Opened by  180
# opened_at           2016-02-29 06:58:00  2016-02-29 07:08:00
# contact_type                      Phone                Phone
# location                    Location 93          Location 93
# category                    Category 53          Category 20
# subcategory             Subcategory 168      Subcategory 125
# impact                       2 - Medium           2 - Medium
# urgency                      2 - Medium           2 - Medium
# priority                   3 - Moderate         3 - Moderate
# assigned_to                         NaN                  NaN
# knowledge                          True                 True
# notify                    Do Not Notify        Do Not Notify
# vendor                              NaN                  NaN
# target_days                           5                    5
#
#                                   6                    7      \
# Id                           INC0000064           INC0000065
# reassignment_count                    0                    0
# reopen_count                          0                    0
# update_count                          0                    0
# made_sla                           True                 True
# opened_by                Opened by  131       Opened by  131
# opened_at           2016-02-29 07:10:00  2016-02-29 07:38:00
# contact_type                      Phone                Phone
# location                   Location 143         Location 108
# category                    Category 53          Category 44
# subcategory             Subcategory 168      Subcategory 229
# impact                       2 - Medium           2 - Medium
# urgency                      2 - Medium           2 - Medium
# priority                   3 - Moderate         3 - Moderate
# assigned_to                 Resolver 78         Resolver 216
# knowledge                          True                 True
# notify                    Do Not Notify        Do Not Notify
# vendor                              NaN                  NaN
# target_days                           8                    7
#
#                                   8                    9      ...  \
# Id                           INC0000066           INC0000067  ...
# reassignment_count                    0                    0  ...
# reopen_count                          0                    0  ...
# update_count                          0                    0  ...
# made_sla                           True                 True  ...
# opened_by                 Opened by  24       Opened by  180  ...
# opened_at           2016-02-29 08:03:00  2016-02-29 08:03:00  ...
# contact_type                      Phone                Phone  ...
# location                   Location 161         Location 143  ...
# category                    Category 55           Category 9  ...
# subcategory             Subcategory 185      Subcategory 110  ...
# impact                       2 - Medium           2 - Medium  ...
# urgency                      2 - Medium           2 - Medium  ...
# priority                   3 - Moderate         3 - Moderate  ...
# assigned_to                         NaN         Resolver 236  ...
# knowledge                          True                 True  ...
# notify                    Do Not Notify        Do Not Notify  ...
# vendor                              NaN                  NaN  ...
# target_days                           7                    7  ...
#
#                                   19990                19991  \
# Id                           INC0028188           INC0028190
# reassignment_count                    0                    0
# reopen_count                          0                    0
# update_count                          0                    0
# made_sla                           True                 True
# opened_by                 Opened by  24       Opened by  301
# opened_at           2016-05-11 08:41:00  2016-05-11 08:41:00
# contact_type                      Phone                Phone
# location                   Location 161          Location 56
# category                     Category 9          Category 37
# subcategory             Subcategory 164      Subcategory 123
# impact                       2 - Medium           2 - Medium
# urgency                      2 - Medium           2 - Medium
# priority                   3 - Moderate         3 - Moderate
# assigned_to                 Resolver 24          Resolver 82
# knowledge                         False                False
# notify                    Do Not Notify        Do Not Notify
# vendor                              NaN                  NaN
# target_days                           6                  217
#
#                                   19992                19993  \
# Id                           INC0028191           INC0028192
# reassignment_count                    0                    0
# reopen_count                          0                    0
# update_count                          0                    0
# made_sla                           True                 True
# opened_by                Opened by  131        Opened by  62
# opened_at           2016-05-11 08:42:00  2016-05-11 08:44:00
# contact_type                      Phone                Phone
# location                   Location 161         Location 143
# category                    Category 42          Category 53
# subcategory             Subcategory 223      Subcategory 303
# impact                       2 - Medium           2 - Medium
# urgency                      2 - Medium           2 - Medium
# priority                   3 - Moderate         3 - Moderate
# assigned_to                Resolver 194          Resolver 33
# knowledge                         False                False
# notify                    Do Not Notify        Do Not Notify
# vendor                              NaN                  NaN
# target_days                           5                    5
#
#                                   19994                19995  \
# Id                           INC0028193           INC0028195
# reassignment_count                    0                    0
# reopen_count                          0                    0
# update_count                          0                    0
# made_sla                           True                 True
# opened_by                 Opened by  24        Opened by  17
# opened_at           2016-05-11 08:44:00  2016-05-11 08:45:00
# contact_type                      Phone                Phone
# location                   Location 108         Location 204
# category                    Category 20          Category 42
# subcategory             Subcategory 174      Subcategory 223
# impact                       2 - Medium           2 - Medium
# urgency                      2 - Medium           2 - Medium
# priority                   3 - Moderate         3 - Moderate
# assigned_to                 Resolver 93          Resolver 13
# knowledge                         False                False
# notify                    Do Not Notify        Do Not Notify
# vendor                              NaN                  NaN
# target_days                           6                    5
#
#                                   19996                19997  \
# Id                           INC0028196           INC0028200
# reassignment_count                    0                    0
# reopen_count                          0                    0
# update_count                          0                    0
# made_sla                           True                 True
# opened_by                 Opened by  17        Opened by  24
# opened_at           2016-05-11 08:46:00  2016-05-11 08:50:00
# contact_type                      Phone                Phone
# location                    Location 93          Location 97
# category                    Category 37          Category 42
# subcategory             Subcategory 174      Subcategory 223
# impact                       2 - Medium           2 - Medium
# urgency                      2 - Medium           2 - Medium
# priority                   3 - Moderate         3 - Moderate
# assigned_to                 Resolver 83          Resolver 17
# knowledge                         False                False
# notify                    Do Not Notify        Do Not Notify
# vendor                              NaN                  NaN
# target_days                           5                    5
#
#                                   19998                19999
# Id                           INC0028201           INC0028203
# reassignment_count                    0                    0
# reopen_count                          0                    0
# update_count                          0                    0
# made_sla                           True                 True
# opened_by                 Opened by  24        Opened by  55
# opened_at           2016-05-11 08:51:00  2016-05-11 08:52:00
# contact_type                      Phone                Phone
# location                    Location 51         Location 204
# category                    Category 53          Category 26
# subcategory             Subcategory 130      Subcategory 275
# impact                       2 - Medium           2 - Medium
# urgency                      2 - Medium           2 - Medium
# priority                   3 - Moderate         3 - Moderate
# assigned_to                         NaN                  NaN
# knowledge                         False                False
# notify                    Do Not Notify        Do Not Notify
# vendor                              NaN                  NaN
# target_days                          11                    5
#
# [19 rows x 20000 columns]
